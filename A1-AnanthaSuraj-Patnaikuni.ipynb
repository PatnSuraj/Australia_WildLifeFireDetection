# %% [markdown]
# <h1><center>CSCI - 4146 - The Process of Data Science - Summer 2022</h1></center>
# <h1><center>Assignment 1</h1></center>
#
# <b>Anantha Suraj Patnaikuni</b>
#
# <b>B00845171</b>

# %% [markdown]
# Referred tutorial slides for referrences in some answers in the assignment

# %% [markdown]
# **Importing necessary libraries to get the datasets from the local computer**

# %%
# importing libraries
import pandas as pd
import numpy as np
from google.colab import files


# files getting uploaded from local drive (respective should be downloaded and saved in the local drive to open the file here) and reads the content in it

uploadFile = files.upload()
import io
print("\nGetting the dataset the dataset ... \n")
fire_nrt = pd.read_csv(io.BytesIO(uploadFile['fire_nrt_M-C61_212899.csv']))
fire_nrt
# Out:
#      <input type="file" id="files-c7592c60-d9ea-4a25-87f8-ec52e274b1b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7592c60-d9ea-4a25-87f8-ec52e274b1b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fire_nrt_M-C61_212899.csv to fire_nrt_M-C61_212899 (1).csv
#
# Getting the dataset the dataset ...
#       latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0     44.27600   23.10700      302.70  2.10   1.40  2021-07-21       105
# 1     44.37300   22.96800      340.50  2.10   1.40  2021-07-21       850
# 2     44.37100   22.99500      342.50  2.10   1.40  2021-07-21       850
# 3     44.36000   22.96600      316.20  2.10   1.40  2021-07-21       850
# 4     44.37000   23.00100      335.90  2.10   1.40  2021-07-21       850
# ...

# %% [markdown]
# **Choice of sampling for limiting the dataset**:
# As the dataset is quite large, I used random subsampling for sampling the largest dataset into the smaller one with at least 150k instances in it, so that the data instance prediction does not affect the wrong output. I used random sampling because, it can randomly select some proportional number of rows for a data needed from the large dataset and helps in getting the output without any differentiation or bias.

# %%
# importing libraries
import pandas as pd
import numpy as np
from google.colab import files

# random subsampling the data as the raw dataset is quite large


# files getting uploaded from local drive (respective should be downloaded and saved in the local drive to open the file here) and reads the content in it
# choosing the actual file and extracting the random data samples for modis_2017_Australia.csv dataset

uploadFile = files.upload()
import io
print("\nRandom sampling the dataset ... \n")
modis_2017 = pd.read_csv(io.BytesIO(uploadFile['modis_2017_Australia.csv']))

modis_2017_sampled_rows = modis_2017.sample(frac =0.55)
  
modis_2017_sampled_rows
# Out:
#      <input type="file" id="files-9e10b058-5253-4a8a-8e31-684ca6e72175" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e10b058-5253-4a8a-8e31-684ca6e72175">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modis_2017_Australia.csv to modis_2017_Australia (1).csv
#
# Random sampling the dataset ...
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 174856  -20.6366   125.4423       389.8   1.0    1.0  2017-10-05       529
# 132377  -28.8757   152.8549       311.2   1.0    1.0  2017-09-08      1505
# 7707    -30.2272   116.6200       350.3   1.7    1.3  2017-03-16       545
# 54798   -16.8429   124.0686       319.5   1.9    1.3  2017-05-18       506
# ...

# %%
# choosing the actual file and extracting the random data samples for modis_2018_Australia.csv dataset

uploadFile = files.upload()
import io

print("\nRandom sampling the dataset ... \n")
modis_2018 = pd.read_csv(io.BytesIO(uploadFile['modis_2018_Australia.csv']))

modis_2018_sampled_rows = modis_2018.sample(frac =0.50)
  
modis_2018_sampled_rows
# Out:
#      <input type="file" id="files-64d287f9-9884-47da-b019-d334d4bda722" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64d287f9-9884-47da-b019-d334d4bda722">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modis_2018_Australia.csv to modis_2018_Australia (1).csv
#
# Random sampling the dataset ...
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 296944  -22.1662   117.8715       322.4   1.0    1.0  2018-12-11      1454
# 235752  -42.3474   147.7979       321.7   1.4    1.2  2018-11-01       433
# 76309   -14.3668   131.2056       320.2   1.7    1.3  2018-05-15       117
# 35035   -15.4479   126.0414       338.0   1.0    1.0  2018-04-17       519
# ...

# %%
# choosing the actual file and extracting the random data samples for modis_2019_Australia.csv dataset

uploadFile = files.upload()
import io

print("\nRandom sampling the dataset ... \n")
modis_2019 = pd.read_csv(io.BytesIO(uploadFile['modis_2019_Australia.csv']))

modis_2019_sampled_rows = modis_2019.sample(frac =0.50)

modis_2019_sampled_rows
# Out:
#      <input type="file" id="files-1bdc80eb-7f35-48fc-89ee-ae175880cc19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bdc80eb-7f35-48fc-89ee-ae175880cc19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modis_2019_Australia.csv to modis_2019_Australia (1).csv
#
# Random sampling the dataset ...
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 236887  -24.7827   146.9815       322.6   1.6    1.2  2019-12-04      1237
# 199380  -29.2704   151.5176       320.2   1.2    1.1  2019-11-11      1230
# 61492   -17.6841   123.4253       333.3   1.0    1.0  2019-05-04       530
# 200081  -30.9527   152.3456       331.6   1.0    1.0  2019-11-12       347
# ...

# %%
# choosing the actual file and extracting the random data samples for modis_2020_Australia.csv dataset

uploadFile = files.upload()
import io

print("\nRandom sampling the dataset ... \n")
modis_2020 = pd.read_csv(io.BytesIO(uploadFile['modis_2020_Australia.csv']))

modis_2020_sampled_rows = modis_2020.sample(frac =0.97)
  
modis_2020_sampled_rows
# Out:
#      <input type="file" id="files-4a8c859f-e540-4a42-ad45-40cd74a57fe1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a8c859f-e540-4a42-ad45-40cd74a57fe1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving modis_2020_Australia.csv to modis_2020_Australia (1).csv
#
# Random sampling the dataset ...
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 25315   -37.2909   149.5393       419.1   1.1    1.0  2020-01-11       410
# 23604   -36.6441   146.5930       321.2   1.0    1.0  2020-01-08      1305
# 127166  -12.4009   142.9053       331.2   2.7    1.6  2020-10-31       340
# 28318   -32.6645   150.0679       345.5   1.0    1.0  2020-01-13       359
# ...

# %% [markdown]
# ---
#
#
#
# **1. Data Exploration and preprocessing**

# %% [markdown]
# > **1. Data Quality Report**

# %% [markdown]
# > **a. Generate data quality reports for the continuous and the categorical features of the data set**

# %%
#Referred tutorial 2 for continous and categorical feature structure report building. 
# Accessed on June 11th 2022

from matplotlib import pyplot as plt
import warnings
# Data Quality report for Continous features of the data set
def continuous_features_report(data_set):

    stats = {
        "Min": lambda df: df.min(),
        "1st Qrt.": lambda df: df.quantile(0.25),
        "Mean": lambda df: df.mean(),
        "Median": lambda df: df.median(),
        "3rd Qrt": lambda df: df.quantile(0.75),
        "Max": lambda df: df.max(),
        "Std. Dev.": lambda df: df.std(),
        "Count": len,
        "Miss %": lambda df: df.isna().sum() / len(df) * 100,
        "Card.": lambda df: df.nunique()
    }


    continous_feature_names = data_set.select_dtypes("number").columns
    continuous_dataframeValues = data_set[continous_feature_names]

    report_df = pd.DataFrame(index=continous_feature_names, columns=stats.keys())

    for stat_name, fn in stats.items():
        # Warnings for empty features
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=RuntimeWarning)
            report_df[stat_name] = fn(continuous_dataframeValues)

    return report_df



# Continous data reports for modis_2017_Australia and its visualization

modis_2017_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2017_sampled_rows.hist(column=['acq_time','frp']);

print("Continous feature data report analysis for Australia's 2017 busfire\n")
continuous_features_report(modis_2017_sampled_rows)
# Out:
# Continous feature data report analysis for Australia's 2017 busfire
#                  Min    1st Qrt.        Mean     Median     3rd Qrt  \
# latitude    -43.4316  -24.435500  -21.204076  -19.76510  -16.383825
# longitude   113.6812  125.978925  132.715555  131.30985  138.874500
# brightness  300.0000  317.700000  332.707775  328.60000  341.600000
# scan          1.0000    1.100000    1.714952    1.30000    2.000000
# track         1.0000    1.000000    1.243103    1.10000    1.400000
# acq_time      0.0000  211.000000  579.626216  446.00000  554.000000
# confidence    0.0000   57.000000   71.351133   74.00000   90.000000
# version       6.2000    6.200000    6.200000    6.20000    6.200000
# bright_t31  266.3000  296.200000  303.591318  303.40000  310.300000
# frp           0.0000   14.700000   72.786860   29.00000   66.300000
# type          0.0000    0.000000    0.009047    0.00000    0.000000
#
#                   Max     Std. Dev.   Count  Miss %   Card.
# ...

# %%
# Continous data reports for modis_2018_Australia and its visualization
modis_2018_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2018_sampled_rows.hist(column=['frp','type'])

print("Continous feature data report analysis for Australia's 2018 busfire\n")
continuous_features_report(modis_2018_sampled_rows)
# Out:
# Continous feature data report analysis for Australia's 2018 busfire
#                  Min    1st Qrt.        Mean     Median   3rd Qrt        Max  \
# latitude    -43.4900  -24.131375  -20.037261  -17.96065  -15.0017    -9.2467
# longitude   113.3681  125.967475  133.132012  131.58810  141.8131   153.5836
# brightness  300.0000  318.400000  332.309731  328.80000  341.0000   503.6000
# scan          1.0000    1.100000    1.696022    1.30000    2.0000     4.8000
# track         1.0000    1.000000    1.238222    1.10000    1.4000     2.0000
# acq_time      0.0000  212.000000  587.581546  442.00000  557.0000  2359.0000
# confidence    0.0000   56.000000   70.747553   74.00000   89.0000   100.0000
# version       6.0300    6.030000    6.030000    6.03000    6.0300     6.0300
# bright_t31  265.7000  297.000000  303.776195  303.80000  310.1000   400.1000
# frp           0.0000   14.600000   66.404211   28.40000   62.4000  7395.4000
# ...

# %%
# Continous data reports for modis_2019_Australia and its visualization
modis_2019_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2019_sampled_rows.hist(column=['acq_time','bright_t31'])

print("Continous feature data report analysis for Australia's 2019 busfire\n")
continuous_features_report(modis_2019_sampled_rows)
# Out:
# Continous feature data report analysis for Australia's 2019 busfire
#                  Min    1st Qrt.        Mean     Median      3rd Qrt  \
# latitude    -43.4079  -31.341375  -23.997487  -25.47760   -15.322575
# longitude   113.4707  128.437200  137.897052  136.75815   150.054100
# brightness  300.0000  317.800000  334.141701  329.70000   343.400000
# scan          1.0000    1.100000    1.630514    1.30000     1.900000
# track         1.0000    1.000000    1.217663    1.10000     1.300000
# acq_time      0.0000  323.000000  693.420808  450.00000  1254.000000
# confidence    0.0000   56.000000   72.030198   76.00000    93.000000
# version       6.0300    6.030000    6.030000    6.03000     6.030000
# bright_t31  265.9000  294.700000  302.823181  302.00000   309.900000
# frp           0.0000   15.300000   76.355133   30.30000    67.400000
# type          0.0000    0.000000    0.014062    0.00000     0.000000
#
#                   Max   Std. Dev.   Count  Miss %   Card.
# ...

# %%
# Continous data reports for modis_2020_Australia and its visualization

modis_2020_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2020_sampled_rows.hist(column=['track','bright_t31'])

print("Continous feature data report analysis for Australia's 2020 busfire\n")
continuous_features_report(modis_2020_sampled_rows)
# Out:
# Continous feature data report analysis for Australia's 2020 busfire
#                  Min    1st Qrt.        Mean     Median   3rd Qrt         Max  \
# latitude    -43.5006  -32.664875  -22.990180  -19.39600  -14.4146     -9.2741
# longitude   113.7342  131.028300  138.716425  142.04275  148.1898    153.5515
# brightness  300.0000  317.500000  331.652757  327.10000  339.1000    507.0000
# scan          1.0000    1.000000    1.581322    1.20000    1.8000      4.8000
# track         1.0000    1.000000    1.201049    1.10000    1.3000      2.0000
# acq_time      0.0000  328.000000  621.626324  436.00000  640.0000   2359.0000
# confidence    0.0000   54.000000   69.251985   72.00000   88.0000    100.0000
# version       6.0300    6.030000    6.030000    6.03000    6.0300      6.0300
# bright_t31  265.9000  295.200000  302.302117  302.20000  308.2000    400.1000
# frp         -29.9000   13.100000   62.379383   24.90000   52.8000  11164.1000
# ...

# %%
# Continous data reports for fire_nrt_M and its visualizaion

fire_nrt.hist(column=['latitude', 'longitude', 'brightness']);
fire_nrt.hist(column=['track','frp'])

print("Continous feature data report analysis for Australia's fire_nrt_M busfire\n")
continuous_features_report(fire_nrt)
# Out:
# Continous feature data report analysis for Australia's fire_nrt_M busfire
#                   Min    1st Qrt.         Mean       Median      3rd Qrt  \
# latitude     37.38966   41.091797    43.105213    43.907765    44.859403
# longitude     9.93419   16.186093    21.094351    21.660310    24.400770
# brightness  300.09000  317.350000   326.180508   325.465000   333.362500
# scan          1.00000    1.040000     1.579462     1.230000     1.720000
# track         1.00000    1.020000     1.201703     1.100000     1.300000
# acq_time      9.00000  935.000000  1166.387097  1115.000000  1210.000000
# confidence    0.00000   58.000000    70.261051    73.000000    84.000000
# bright_t31  276.28000  297.225000   303.249707   304.095000   309.107500
# frp           3.44000   11.107500    34.330030    18.540000    36.485000
#
#                    Max   Std. Dev.  Count  Miss %  Card.
# latitude      48.80219    2.700031   1674     0.0   1654
# ...

# %%
#Referred tutorial 2 code for continous and categorical feature structure report building. 
# Accessed on June 11th 2022

# Data Quality report for Categorical features of the data set

def categorical_features_report(data_set):


    def _mode(df):
        return df.apply(lambda ft: ft.mode().to_list())

    def _mode_freq(df):
        return df.apply(lambda ft: ft.value_counts()[ft.mode()].sum())

    def _second_mode(df):
        return df.apply(lambda ft: ft[~ft.isin(ft.mode())].mode().to_list())

    def _second_mode_freq(df):
        return df.apply(
            lambda ft: ft[~ft.isin(ft.mode())]
            .value_counts()[ft[~ft.isin(ft.mode())].mode()]
            .sum()
        )

    stats = {
        "Mode": _mode,
        "2nd Mode": _second_mode,
        "Mode Freq": _mode_freq,
        "Mode %": lambda df: _mode_freq(df) / len(df) * 100,
        "2nd Mode Freq": _second_mode_freq,
        "2nd Mode %": lambda df: _second_mode_freq(df) / len(df) * 100,
        "Count": len,
        "Miss %": lambda df: df.isna().sum() / len(df) * 100,
        "Card.": lambda df: df.nunique()
    }


    categorical_feature_names = data_set.select_dtypes("number").columns
    continuous_data_dataframe = data_set[categorical_feature_names]

    report_df = pd.DataFrame(index=categorical_feature_names, columns=stats.keys())

    for stat_name, fn in stats.items():
        # Warnings for empty features
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=RuntimeWarning)
            report_df[stat_name] = fn(continuous_data_dataframe)

    return report_df


# Catagorical data reports for modis_2017_Australia and its visualizaion

modis_2017_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2017_sampled_rows.hist(column=['track','bright_t31'])

print("Categorical feature data report analysis for Australia's 2017 busfire\n")
categorical_features_report(modis_2017_sampled_rows)
# Out:
# Categorical feature data report analysis for Australia's 2017 busfire
#                                      Mode  \
# latitude                        [-21.699]
# longitude   [128.8793, 132.5854, 132.982]
# brightness                        [328.9]
# scan                                [1.0]
# track                               [1.0]
# acq_time                            [500]
# confidence                          [100]
# version                             [6.2]
# bright_t31                        [303.7]
# frp                            [8.1, 9.9]
# type                                  [0]
#
#                                                      2nd Mode  Mode Freq  \
# latitude                                           [-20.5987]         10
# longitude   [125.1558, 125.3231, 125.4465, 126.7772, 126.7...         21
# brightness                                            [328.7]        514
# scan                                                    [1.1]      32160
# ...

# %%
# Catagorical data reports for modis_2018_Australia and its visualizaion

modis_2018_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2018_sampled_rows.hist(column=['version','frp'])

print("Categorical feature data report analysis for Australia's 2018 busfire\n")
categorical_features_report(modis_2018)
# Out:
# Categorical feature data report analysis for Australia's 2018 busfire
#                             Mode  \
# latitude    [-21.6968, -13.4402]
# longitude             [130.2534]
# brightness               [328.9]
# scan                       [1.0]
# track                      [1.0]
# acq_time                   [436]
# confidence                 [100]
# version                   [6.03]
# bright_t31               [305.0]
# frp                       [11.7]
# type                         [0]
#
#                                                      2nd Mode  Mode Freq  \
# latitude              [-21.6982, -16.7837, -16.7473, -15.246]         24
# longitude   [126.9823, 127.0115, 130.3839, 130.9198, 131.1...         10
# brightness                                            [328.6]       1114
# scan                                                    [1.1]      67805
# track                                                   [1.1]      96770
# ...

# %%
# Catagorical data reports for modis_2019_Australia and its visualizaion

modis_2019_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2019_sampled_rows.hist(column=['version','frp'])


print("Categorical feature data report analysis for Australia's 2019 busfire\n")
# categorical_features_report(modis_2019)
modis_2019
# Out:
# Categorical feature data report analysis for Australia's 2019 busfire
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       -13.9873   127.3882       324.2   2.6    1.5  2019-01-01       122
# 1       -13.9916   127.4121       327.4   2.6    1.5  2019-01-01       122
# 2       -14.0055   127.4097       328.8   2.6    1.5  2019-01-01       122
# 3       -14.1017   127.4337       334.9   2.6    1.5  2019-01-01       122
# 4       -14.0012   127.3857       349.5   2.6    1.5  2019-01-01       122
# ...          ...        ...         ...   ...    ...         ...       ...
# 310479  -34.8709   150.1268       311.2   4.0    1.9  2019-12-31      2318
# 310480  -32.5872   150.4455       315.3   4.4    1.9  2019-12-31      2318
# 310481  -33.8106   150.1615       310.8   4.2    1.9  2019-12-31      2318
# 310482  -34.3508   150.3523       316.0   4.0    1.9  2019-12-31      2318
# 310483  -41.5859   147.9286       314.4   3.4    1.7  2019-12-31      2320
# ...

# %%
# Catagorical data reports for modis_2020_Australia and its visualizaion

modis_2020_sampled_rows.hist(column=['latitude', 'longitude', 'brightness']);
modis_2020_sampled_rows.hist(column=['track','bright_t31'])


print("Categorical feature data report analysis for Australia's 2020 busfire\n")
categorical_features_report(modis_2020)
# Out:
# Categorical feature data report analysis for Australia's 2020 busfire
#                             Mode  \
# latitude              [-35.8493]
# longitude   [149.3713, 149.4987]
# brightness               [328.8]
# scan                       [1.0]
# track                      [1.0]
# acq_time                   [404]
# confidence                 [100]
# version                   [6.03]
# bright_t31               [305.4]
# frp                        [0.0]
# type                         [0]
#
#                                                      2nd Mode  Mode Freq  \
# latitude                                  [-37.3197, -37.068]         10
# longitude   [121.4971, 148.9213, 149.3231, 149.3615, 149.4...         18
# brightness                                            [328.9]        598
# scan                                                    [1.1]      40498
# track                                                   [1.1]      58159
# ...

# %%
# Categorical data reports for fire_nrt_M and its visualizaion

fire_nrt.hist(column=['latitude', 'longitude', 'brightness']);
fire_nrt.hist(column=['track','frp'])

print("Continous feature data report analysis for Australia's fire_nrt_M busfire\n")
categorical_features_report(fire_nrt)
# Out:
# Continous feature data report analysis for Australia's fire_nrt_M busfire
#                                  Mode  \
# latitude                     [45.764]
# longitude                    [22.858]
# brightness             [321.0, 331.6]
# scan                            [1.0]
# track                           [1.0]
# acq_time                       [1157]
# confidence                      [100]
# bright_t31                    [303.4]
# frp         [8.2, 10.57, 10.6, 15.94]
#
#                                                      2nd Mode  Mode Freq  \
# latitude    [37.84, 37.842, 40.62754, 40.793, 41.087, 41.4...          3
# longitude   [9.943, 12.27, 14.495, 21.18696, 22.755, 22.76...          3
# brightness  [317.9, 320.6, 320.9, 321.2, 322.3, 322.7, 323...         10
# scan                                                   [1.02]        125
# track                                                  [1.01]        216
# ...

# %% [markdown]
# > **b. Plot the heatmap correlation among the variables in the data**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# correlation among variables for 2017 sampled data
plt.figure(figsize=(20, 10))
correl_heatmap = sns.heatmap(modis_2017_sampled_rows.corr(), annot = True)
correl_heatmap.set(title="Correlation among the modis_2017 data variables\n");

# %%
# correlation among variables for 2018 sampled data
plt.figure(figsize=(20, 10))
correl_heatmap = sns.heatmap(modis_2018.corr(), annot = True)
correl_heatmap.set(title="Correlation among the modis_2018 data variables\n");

# %%
# correlation among variables for 2019 sampled data
plt.figure(figsize=(20, 10))
correl_heatmap = sns.heatmap(modis_2019.corr(), annot = True)
correl_heatmap.set(title="Correlation among the modis_2019 data variables\n");

# %%
# correlation among variables for 2020 sampled data
plt.figure(figsize=(20, 10))
correl_heatmap = sns.heatmap(modis_2020.corr(), annot = True)
correl_heatmap.set(title="Correlation among the modis_2020 data variables\n");

# %%
# correlation among variables for fire_nrt_M data
plt.figure(figsize=(20, 10))
correl_heatmap = sns.heatmap(fire_nrt.corr(), annot = True)
correl_heatmap.set(title="Correlation among the fire_nrt data variables\n");

# %% [markdown]
# > **c. Identify data quality issues and build the data quality plan**

# %% [markdown]
# > Data quality issues are the issues caused due to the inefficiency in dataset. Some of the key issues caused for bad data quality is having duplicate values, some incompleted data variables/values in the dataset, null value segments, missing important parts of the data values, etc.
#
# > Data planning is defined as improving the data set with good accuracy, integrity and relevancy. It results in highest accuracy with low bias.
#
# > We can eradicate or solve the data quality issues by analysing and implementing some data plan approaches. This can eliminate null values,remove outliers from dataset if there are any, etc. Some of the values in the dataset may include null values. We can remove them using some nullvalue method helpers in python like, isnull(), dropna() (both for rows and columns in dataset) and fillna() to replac it with 0.

# %% [markdown]
# **2. Preprocess your data according to the data quality plan**

# %%
#processing the data plan

# Dropping null values from the dataset and filling them with 0 to improve accuracy and data quality
modis_2017_sampled_rows.dropna()
modis_2017_sampled_rows.dropna(axis='columns')
modis_2017_sampled_rows.fillna(0)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 174856  -20.6366   125.4423       389.8   1.0    1.0  2017-10-05       529
# 132377  -28.8757   152.8549       311.2   1.0    1.0  2017-09-08      1505
# 7707    -30.2272   116.6200       350.3   1.7    1.3  2017-03-16       545
# 54798   -16.8429   124.0686       319.5   1.9    1.3  2017-05-18       506
# 60511   -33.3842   138.6290       310.0   2.2    1.4  2017-05-26       412
# ...          ...        ...         ...   ...    ...         ...       ...
# 9155    -20.0002   124.8641       309.8   1.1    1.1  2017-03-19      1713
# 154746  -19.1747   125.1297       448.9   1.1    1.1  2017-09-22      1653
# 159670  -20.3795   124.9642       350.1   1.6    1.3  2017-09-24       547
# 16831   -34.7805   147.2670       320.4   1.9    1.3  2017-04-04       436
# 157165  -18.7332   130.3781       347.2   1.0    1.0  2017-09-23       505
#
# ...

# %%
modis_2018_sampled_rows.dropna()
modis_2018_sampled_rows.dropna(axis='columns')
modis_2018_sampled_rows.fillna(0)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 296944  -22.1662   117.8715       322.4   1.0    1.0  2018-12-11      1454
# 235752  -42.3474   147.7979       321.7   1.4    1.2  2018-11-01       433
# 76309   -14.3668   131.2056       320.2   1.7    1.3  2018-05-15       117
# 35035   -15.4479   126.0414       338.0   1.0    1.0  2018-04-17       519
# 97337   -12.6711   131.1492       339.6   1.2    1.1  2018-06-01       449
# ...          ...        ...         ...   ...    ...         ...       ...
# 86133   -18.4319   124.9393       335.4   3.0    1.6  2018-05-20       601
# 287664  -18.7852   142.8722       316.4   1.0    1.0  2018-12-04      1310
# 5805    -30.2747   150.9211       327.4   1.6    1.2  2018-01-18      1307
# 23079   -25.8741   131.1088       357.2   3.4    1.7  2018-04-04       546
# 95914   -30.6168   147.8053       307.2   1.0    1.0  2018-05-31       400
#
# ...

# %%
modis_2019_sampled_rows.dropna()
modis_2019_sampled_rows.dropna(axis='columns')
modis_2019_sampled_rows.fillna(0)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 236887  -24.7827   146.9815       322.6   1.6    1.2  2019-12-04      1237
# 199380  -29.2704   151.5176       320.2   1.2    1.1  2019-11-11      1230
# 61492   -17.6841   123.4253       333.3   1.0    1.0  2019-05-04       530
# 200081  -30.9527   152.3456       331.6   1.0    1.0  2019-11-12       347
# 81241   -12.2074   132.4923       320.0   1.5    1.2  2019-06-06       436
# ...          ...        ...         ...   ...    ...         ...       ...
# 184897  -30.0688   152.6248       301.7   2.1    1.4  2019-11-05      1306
# 282171  -18.4820   141.5009       338.5   1.9    1.3  2019-12-21       357
# 59366   -36.7778   141.7774       311.7   2.3    1.5  2019-04-29       506
# 167862  -12.4104   142.6151       342.8   1.5    1.2  2019-10-18       109
# 119747  -29.8898   152.8660       303.7   1.0    1.0  2019-08-05      1242
#
# ...

# %%
modis_2020_sampled_rows.dropna()
modis_2020_sampled_rows.dropna(axis='columns')
modis_2020_sampled_rows.fillna(0)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 25315   -37.2909   149.5393       419.1   1.1    1.0  2020-01-11       410
# 23604   -36.6441   146.5930       321.2   1.0    1.0  2020-01-08      1305
# 127166  -12.4009   142.9053       331.2   2.7    1.6  2020-10-31       340
# 28318   -32.6645   150.0679       345.5   1.0    1.0  2020-01-13       359
# 111184  -28.2857   150.4493       319.7   4.1    1.9  2020-09-13        55
# ...          ...        ...         ...   ...    ...         ...       ...
# 17484   -31.5107   151.2416       321.5   1.0    1.0  2020-01-04      1506
# 140839  -16.3803   137.3969       340.8   1.3    1.1  2020-11-17       422
# 32687   -35.7797   149.8398       336.5   1.1    1.1  2020-01-26      2355
# 58235   -14.2136   136.7820       316.5   1.0    1.0  2020-05-04       116
# 10225   -35.8258   148.6594       328.5   1.2    1.1  2020-01-03      1246
#
# ...

# %% [markdown]
# 3. Answer the following questions:
#
#
# > a. What are the dates on which bushfires present the high number of
# incidents?
#
#
# > From the data that I retrieved from all the years, the dates in which the bushfires present for high number of incidents are during 2017 bushfires (2017-11-28), as it have the acq_time of 628, which is more when compared with other four years.

# %%
# Referrence: AUSTRALIA WILDFIRE 2020 / INVESTIGATION FOR TURKEY. (2022). 
# Retrieved 12th June 2022, from https://www.kaggle.com/code/brsdincer/australia-wildfire-2020-investigation-for-turkey

# acquiring the dates in which the highest number of bushfire incidents happened
print(modis_2017_sampled_rows[modis_2017_sampled_rows["frp"] == modis_2017_sampled_rows["frp"].max()])
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 236644  -30.2312   123.6196       462.6   4.4    1.9  2017-11-28       628
#
#        satellite instrument  confidence  version  bright_t31     frp daynight  \
# 236644      Aqua      MODIS         100      6.2       331.3  7401.1        D
#
#         type
# 236644     0

# %%
print(modis_2018_sampled_rows[modis_2018_sampled_rows["frp"] == modis_2018_sampled_rows["frp"].max()])
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 178979  -22.8348   122.7901       455.9   4.8    2.0  2018-09-28       452
#
#        satellite instrument  confidence  version  bright_t31     frp daynight  \
# 178979      Aqua      MODIS         100     6.03       325.3  7395.4        D
#
#         type
# 178979     0

# %%
print(modis_2019_sampled_rows[modis_2019_sampled_rows["frp"] == modis_2019_sampled_rows["frp"].max()])
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 20614  -37.3146   148.1351       484.4   3.4    1.7  2019-01-25       453
#
#       satellite instrument  confidence  version  bright_t31     frp daynight  \
# 20614      Aqua      MODIS         100     6.03       317.0  7454.5        D
#
#        type
# 20614     0

# %%
print(modis_2020_sampled_rows[modis_2020_sampled_rows["frp"] == modis_2020_sampled_rows["frp"].max()])
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 23118  -32.8923   124.0954       486.1   4.5    1.9  2020-01-08       241
#
#       satellite instrument  confidence  version  bright_t31      frp daynight  \
# 23118     Terra      MODIS         100     6.03       321.6  11164.1        D
#
#        type
# 23118     0

# %% [markdown]
# > b. Based on the data quality report, which attributes do you think are useful
# to predict the confidence of an incident? Explain why you think that the
# selected attribute is important.
#
#
# > Based on the data quality report, I believe that frp is one of the attributes which predicts the confidence of an incident. I chose frp as an important attribute because, it senses the fire intensity in the region with its trained datasets and distributes the min-infrared sib pixels of fire characterization with no or less classification errors. This as a result predicts the data well and helps in getting the correct prediction of the incident.

# %% [markdown]
# ---
#
#
# **2. Spatio-temporal data**

# %% [markdown]
# > **1. Plot a geographical heat map of FRP for the Aqua area. Use data from the year
# 2017 and any aggregation method (e.g. mean, summation, maximum, or
# something else) of your choice. Justify your choice of aggregation method.**

# %%
# geographical map for aqua_area

AQUA_area = modis_2017_sampled_rows[modis_2017_sampled_rows["satellite"] == "Aqua"]
# data = pd.read_csv("modis_2017_Australia.csv", usecols=["latitude","longitude","frp", "satellite"])
AQUA_area
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 174856  -20.6366   125.4423       389.8   1.0    1.0  2017-10-05       529
# 132377  -28.8757   152.8549       311.2   1.0    1.0  2017-09-08      1505
# 7707    -30.2272   116.6200       350.3   1.7    1.3  2017-03-16       545
# 54798   -16.8429   124.0686       319.5   1.9    1.3  2017-05-18       506
# 60511   -33.3842   138.6290       310.0   2.2    1.4  2017-05-26       412
# ...          ...        ...         ...   ...    ...         ...       ...
# 9155    -20.0002   124.8641       309.8   1.1    1.1  2017-03-19      1713
# 154746  -19.1747   125.1297       448.9   1.1    1.1  2017-09-22      1653
# 159670  -20.3795   124.9642       350.1   1.6    1.3  2017-09-24       547
# 16831   -34.7805   147.2670       320.4   1.9    1.3  2017-04-04       436
# 157165  -18.7332   130.3781       347.2   1.0    1.0  2017-09-23       505
#
# ...

# %%
# The choice of my aggregation method is mean, because it gives a detailed analysis of current data, which helps further predicting the valid dataset results
AQUA_area.aggregate(['mean','sum', 'min', 'max'])
AQUA_area.hist(column=['latitude', 'longitude', 'frp']);

# %%
# installing gepandas for spatiotemporal data questions
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Reference: The easiest way to plot data from Pandas on a world map. (2022). 
# Retrieved 14 June 2022, from https://towardsdatascience.com/the-easiest-way-to-plot-data-from-pandas-on-a-world-map-1a62962a27f3

import geopandas as gpd
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# ...

# %%
# Extracting the geographical outline of Australia from the list of countries
countries[countries["name"] == "Australia"].plot(color="black")

# %%
AQUA_area.plot(x="longitude",y="latitude", kind="scatter", c="red",colormap="hot_r",title="Australia geographical heat map for FRP according to 2017 data");

# %% [markdown]
# > **2. Mark the “Fire activity” (lat, long = -35.6,149.12) on the city map.**

# %%
import folium
m = folium.Map([-35.6,149.12], tiles = "Stamen Terrain",zoom_start=4.5)
folium.CircleMarker(location=(-35.6,149.12),radius=35, fill_color='red').add_child(folium.Popup('Fire Activity')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > **3. Mark the regions with the highest recorded fire radiation in a day for
# measurements where "acq_date = 2020-01-08".**

# %%
# building a condition according to the dataset conditions mentioned in question
dates="2020-01-08"
# filtering the data appropriately to satisfy the condition
df_filter = modis_2020_sampled_rows['acq_date'] = dates

# let us assume frp above 950 is considered as highest frp of the day
modis_2020_sampled_rows_filter = modis_2020_sampled_rows[modis_2020_sampled_rows['frp'] >= 950]
modis_2020_sampled_rows_filter
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 112424  -16.7729   122.9332       443.0   1.4    1.2  2020-01-08       549
# 6427    -31.2571   121.1769       492.4   1.1    1.0  2020-01-08       557
# 49215   -32.3721   116.2416       413.5   2.1    1.4  2020-01-08       640
# 37434   -36.8577   149.5273       500.0   1.1    1.0  2020-01-08        14
# 64039   -27.8415   114.2130       386.5   3.8    1.8  2020-01-08       534
# ...          ...        ...         ...   ...    ...         ...       ...
# 15597   -34.8579   150.4329       484.4   1.1    1.0  2020-01-08       405
# 13533   -36.9925   146.9074       493.6   1.1    1.0  2020-01-08       404
# 8828    -35.8974   147.4874       390.2   4.2    1.9  2020-01-08       459
# 37942   -36.8708   149.5839       453.6   1.8    1.3  2020-01-08       429
# 30691   -36.9458   147.4161       448.4   1.4    1.2  2020-01-08       429
#
# ...

# %%
import folium
from folium import plugins

locations = modis_2020_sampled_rows[['latitude', 'longitude']]
latlonglocationlist = locations.values.tolist()

map = folium.Map(location=[-26.26,133.16], zoom_start=4.5)
plugins.MarkerCluster(latlonglocationlist[:900]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > **4. Find a visualization to plot the progress of the fire activity across all points from
# Nov 1, 2019, to Jan 31, 2020.**

# %%
# getting the range of dats mentiond in question (2019 to 2020)

rows_concat = pd.concat([modis_2019_sampled_rows, modis_2020])
rows_concat

rows_concat = pd.DataFrame(rows_concat)
start_date = '2019-11-01'
end_date = '2020-01-31'
mask = (rows_concat['acq_date'] >= start_date) & (rows_concat['acq_date'] <= end_date)
  
rows_concat = rows_concat.loc[mask]
rows_concat
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 236887  -24.7827   146.9815       322.6   1.6    1.2  2019-12-04      1237
# 199380  -29.2704   151.5176       320.2   1.2    1.1  2019-11-11      1230
# 200081  -30.9527   152.3456       331.6   1.0    1.0  2019-11-12       347
# 226784  -35.4959   150.0620       391.4   1.2    1.1  2019-11-28       346
# 209398  -30.1342   152.4921       345.8   1.2    1.1  2019-11-15      1518
# ...          ...        ...         ...   ...    ...         ...       ...
# 36989   -30.8685   121.4863       313.2   1.1    1.0  2020-01-31      1452
# 36990   -30.8626   121.4909       310.3   1.1    1.0  2020-01-31      1452
# 36991   -20.7254   139.4791       302.3   1.5    1.2  2020-01-31      1623
# 36992   -20.7364   139.4776       302.2   1.5    1.2  2020-01-31      1623
# 36993   -24.5543   127.8708       302.0   1.9    1.3  2020-01-31      1624
#
# ...

# %%
figure = plt.figure(figsize=(20,10))
sns.lineplot(rows_concat["acq_date"],rows_concat["frp"],color=('green'), label = "Fire activity data from the given period (2019-2020)")
plt.xlabel('Aqua date')
plt.ylabel('Frp')
plt.title("Fire activity in Australia in given time period")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ---
#
#
# **3. Build a model for spatial prediction of  wildfire**

# %% [markdown]
# > **1. In between ‘Brightness temperature I-5’ and ‘Fire Radiative Power’ choose either as the target feature.**
#
#
# > Fetaure selection is used in most of the machine learning concepts. This selection algorithm helps in getting the best feature/variable from the dataset to use in the model for improving the accuracy of the data, getting efficient training time and reducing the error rate of the prediction.
#
#
# > Based on the data and analysis of the feature implementation, the target feature I chose in between temperature I-5 and fire radiative power is "fire radiative power (frp)"

# %% [markdown]
# > **2. Explain what the task you’re solving is (e.g., supervised x unsupervised,
# classification x regression x clustering or similarity matching x, etc)**

# %% [markdown]
# > The method I used in finding the feature selection to the dataset is correlation of the dataset. The correlation feature selection algorithm is used to find the connection or relation between the particular columns of the dataset with all the other columns. I implemented a correlation slection for the dataset with the brightness and frp column. I seperated the data with highest corelation points and decided on which data column has the highest correlation amoing all the others.

# %% [markdown]
# > **3. Use a feature selection method to select the features to build a model.**

# %%
# 2017 dataset
plt.figure(figsize=(12,10))
correl1 = modis_2017_sampled_rows.corr()
sns.heatmap(correl1, annot=True, cmap=plt.cm.Reds)
plt.show()

coln = abs(correl1["frp"])
high_corelatd_features = coln[coln > 0.6]
print("\n",high_corelatd_features)

print("\n",correl1[["brightness","confidence"]].corr())
print(correl1[["brightness","frp"]].corr())
# Out:
#  brightness    0.651765
# frp           1.000000
# Name: frp, dtype: float64
#
#              brightness  confidence
# brightness    1.000000    0.790092
# confidence    0.790092    1.000000
#             brightness       frp
# brightness    1.000000  0.762058
# frp           0.762058  1.000000

# %%
# 2018 dataset
plt.figure(figsize=(12,10))
correl2 = modis_2018_sampled_rows.corr()
sns.heatmap(correl2, annot=True, cmap=plt.cm.Reds)
plt.show()

coln = abs(correl2["frp"])
high_corelatd_features = coln[coln > 0.5]
print("\n",high_corelatd_features)

print("\n",correl2[["brightness","confidence"]].corr())
print(correl2[["brightness","frp"]].corr())
# Out:
#  brightness    0.646477
# frp           1.000000
# Name: frp, dtype: float64
#
#              brightness  confidence
# brightness    1.000000    0.784584
# confidence    0.784584    1.000000
#             brightness       frp
# brightness    1.000000  0.762173
# frp           0.762173  1.000000

# %%
# 2019 dataset
plt.figure(figsize=(12,10))
correl3 = modis_2019_sampled_rows.corr()
sns.heatmap(correl3, annot=True, cmap=plt.cm.Reds)
plt.show()

coln = abs(correl3["frp"])
high_corelatd_features = coln[coln > 0.5]
print("\n",high_corelatd_features)

print("\n",correl3[["brightness","confidence"]].corr())
print(correl3[["brightness","frp"]].corr())
# Out:
#  brightness    0.641617
# frp           1.000000
# Name: frp, dtype: float64
#
#              brightness  confidence
# brightness    1.000000    0.777286
# confidence    0.777286    1.000000
#             brightness       frp
# brightness    1.000000  0.788687
# frp           0.788687  1.000000

# %%
# 2020 dataset
plt.figure(figsize=(12,10))
correl4 = modis_2020_sampled_rows.corr()

sns.heatmap(correl4, annot=True,cmap=plt.cm.Reds)
plt.show()

coln = abs(correl4["frp"])
high_corelatd_features = coln[coln > 0.5]
print("\n",high_corelatd_features)

print("\n",correl4[["brightness","confidence"]].corr())
print(correl4[["brightness","frp"]].corr())
# Out:
#  brightness    0.608986
# frp           1.000000
# Name: frp, dtype: float64
#
#              brightness  confidence
# brightness    1.000000    0.773573
# confidence    0.773573    1.000000
#             brightness       frp
# brightness    1.000000  0.775884
# frp           0.775884  1.000000

# %% [markdown]
# > **4. Select one or more evaluation metrics. Justify your choice.**

# %%
# Getting the accuracy of the models from 2017 to 2020
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

dataset = "modis_2017_Australia.csv"
df = pd.read_csv(dataset)

model = GaussianNB()                       
X_iris = df.drop(['track','acq_date','brightness','scan','satellite','instrument','version','bright_t31','daynight','type'], axis = 1)
y_iris = df['satellite']


Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state=1)

model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)              

print("The accuracy score of the data is","%.2f%%" % (accuracy_score(ytest, y_model) * 100))

X_iris
# Out:
# The accuracy score of the data is 81.07%
#         latitude  longitude  acq_time  confidence   frp
# 0       -23.9083   147.2966        47          53  17.6
# 1       -23.6890   150.0994        47          22  30.0
# 2       -23.5908   150.1676        47          33  35.4
# 3       -22.4119   148.8484        47          26  25.8
# 4       -20.5897   147.6421        47          34  19.0
# ...          ...        ...       ...         ...   ...
# 273307  -22.4323   134.5258      1630          86   9.6
# 273308  -22.4415   134.5244      1630          88  10.6
# 273309  -22.4707   134.5303      1630          83   8.9
# 273310  -22.4800   134.5289      1630          69   6.1
# 273311  -22.2666   136.8796      1630          68   7.4
#
# [273312 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

dataset = "modis_2018_Australia.csv"
df = pd.read_csv(dataset)

model = GaussianNB()                       
X_iris = df.drop(['track','acq_date','brightness','scan','satellite','instrument','version','bright_t31','daynight','type'], axis = 1)
y_iris = df['satellite']


Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state=1)

model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)              

print("The accuracy score of the data is","%.2f%%" % (accuracy_score(ytest, y_model) * 100))

X_iris
# Out:
# The accuracy score of the data is 83.33%
#         latitude  longitude  acq_time  confidence   frp
# 0       -15.5916   143.6943        15          65  38.8
# 1       -17.9494   144.7574        15          63  20.5
# 2       -17.9460   144.7383        15          69  26.2
# 3       -17.8123   144.6511        15          80  60.8
# 4       -17.9161   144.6444        15          41  22.4
# ...          ...        ...       ...         ...   ...
# 307354  -24.6695   148.0981      2347          58  45.0
# 307355  -25.2058   149.1212      2347          62  35.9
# 307356  -24.9143   148.3755      2347          41  25.7
# 307357  -24.9134   148.3822      2347          63  40.4
# 307358  -34.4571   150.8804      2349          49  12.7
#
# [307359 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

dataset = "modis_2019_Australia.csv"
df = pd.read_csv(dataset)

model = GaussianNB()                       
X_iris = df.drop(['track','acq_date','brightness','scan','satellite','instrument','version','bright_t31','daynight','type'], axis = 1)
y_iris = df['satellite']


Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state=1)

model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)              

print("The accuracy score of the data is","%.2f%%" % (accuracy_score(ytest, y_model) * 100))

X_iris
# Out:
# The accuracy score of the data is 77.34%
#         latitude  longitude  acq_time  confidence    frp
# 0       -13.9873   127.3882       122          39   31.0
# 1       -13.9916   127.4121       122          61   45.0
# 2       -14.0055   127.4097       122          27   44.1
# 3       -14.1017   127.4337       122          86   83.1
# 4       -14.0012   127.3857       122          83  182.4
# ...          ...        ...       ...         ...    ...
# 310479  -34.8709   150.1268      2318          13   49.9
# 310480  -32.5872   150.4455      2318          57   44.7
# 310481  -33.8106   150.1615      2318          22   39.5
# 310482  -34.3508   150.3523      2318          63   74.6
# 310483  -41.5859   147.9286      2320          31   60.8
#
# [310484 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

dataset = "modis_2020_Australia.csv"
df = pd.read_csv(dataset)

model = GaussianNB()                

X_iris = df.drop(columns=['frp', 'acq_date', 'satellite', 'instrument', 'daynight'], axis=1)
y_iris = df['satellite']


Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, train_size = 0.5, random_state=1)

model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)              

print("The accuracy score of the data is","%.2f%%" % (accuracy_score(ytest, y_model) * 100))

X_iris
# Out:
# The accuracy score of the data is 71.31%
#         latitude  longitude  brightness  scan  track  acq_time  confidence  \
# 0       -13.2051   143.1472       337.2   1.0    1.0        50          87
# 1       -14.4737   143.5811       351.4   1.0    1.0        51          95
# 2       -14.4828   143.5797       321.6   1.0    1.0        51          58
# 3       -14.7204   143.7693       343.0   1.0    1.0        51          89
# 4       -16.0143   145.1106       322.1   1.2    1.1        51          56
# ...          ...        ...         ...   ...    ...       ...         ...
# 155519  -28.2874   122.2659       309.9   2.2    1.5      1409          31
# 155520  -30.8622   121.4951       308.0   1.2    1.1      1721          73
# 155521  -28.2864   122.2689       319.3   1.2    1.1      1721          65
# 155522  -28.2849   122.2565       345.2   1.2    1.1      1721         100
# 155523  -30.8620   121.4883       303.2   1.2    1.1      1721          54
#
# ...

# %% [markdown]
# **5. Build a baseline model**

# %% [markdown]
# > **1. Perform hyperparameter tuning if applicable.**

# %%
# Reference: https://towardsdatascience.com/hyperparameter-tuning-in-python-21a76794a1f7

from sklearn.model_selection import validation_curve
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import GridSearchCV
# model = LogisticRegression()
grid_vals = {'penalty': ['l1','l2'], 'C': [0.001,0.01,0.1,1]}
grid_lr = GridSearchCV(estimator=model, param_grid=grid_vals, scoring='accuracy', 
                       cv=6, refit=True, return_train_score=True) 

model.fit(Xtrain, ytrain)
preds = model.predict(Xtest)
grid_lr
# Out:
# GridSearchCV(cv=6, estimator=GaussianNB(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1], 'penalty': ['l1', 'l2']},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# > **2. Train and evaluate your model**

# %%
dataframe=pd.read_csv('modis_2017_Australia.csv')
y=dataframe.frp
x=dataframe.drop('frp',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6)

model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)

# %% [markdown]
# > **3. How do you make sure not to overfit?**
#
#
#
# > By using hyperparameter tuning methods like cross validation, traing the data from time to time in order to predict the data with more accuracy. These techniques can help us in making sure that the data is not overfit

# %% [markdown]
# > **4. Visualize the learning process and/or the knowledge acquired by your
# model. Explain why you think this is the right visualization.**

# %%
x=modis_2017_sampled_rows.frp
y=modis_2017_sampled_rows.brightness

plt.figure(figsize=(12, 6))
plt.plot(x, y, color='green', linewidth = 2, marker='o', markerfacecolor='red', markersize=6)
plt.scatter(x,y,cmap='YlGn');

# %%
x1=modis_2020_sampled_rows.frp
y1=modis_2020_sampled_rows.brightness

plt.figure(figsize=(12, 6))
plt.plot(x1, y1, color='green', linewidth = 2, marker='o', markerfacecolor='red', markersize=6)
plt.scatter(x1,y1,cmap='YlGn');

# %% [markdown]
# > **5. Analyze the results**
#
#
#
# > From the above data model implementation for grid search algorithm, we can see that specified subset of finding algorithm through training data model acquired through sequence of probability distributions. The variation between the range of bush fires from 2017 to 2020 had a major impact on radiation powers which are correlated with time.

# %% [markdown]
# **6. Build a candidate final model ( you are encouraged to experiment with more than
# one model but only include and discuss your “best” model)**

# %% [markdown]
# > **1. Perform hyperparameter tuning if applicable.**

# %%
# lets consider 2020 dataset for tuning
modis_2020
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       -13.2051   143.1472       337.2   1.0    1.0  2020-01-01        50
# 1       -14.4737   143.5811       351.4   1.0    1.0  2020-01-01        51
# 2       -14.4828   143.5797       321.6   1.0    1.0  2020-01-01        51
# 3       -14.7204   143.7693       343.0   1.0    1.0  2020-01-01        51
# 4       -16.0143   145.1106       322.1   1.2    1.1  2020-01-01        51
# ...          ...        ...         ...   ...    ...         ...       ...
# 155519  -28.2874   122.2659       309.9   2.2    1.5  2020-12-31      1409
# 155520  -30.8622   121.4951       308.0   1.2    1.1  2020-12-31      1721
# 155521  -28.2864   122.2689       319.3   1.2    1.1  2020-12-31      1721
# 155522  -28.2849   122.2565       345.2   1.2    1.1  2020-12-31      1721
# 155523  -30.8620   121.4883       303.2   1.2    1.1  2020-12-31      1721
#
# ...

# %%
X = modis_2020.drop(columns=['frp', 'acq_date', 'satellite', 'instrument', 'daynight'], axis=1)
y = modis_2020['frp']


X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=1)

rf_model = RandomForestClassifier()
model.fit(Xtrain, ytrain)


y_pred = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_pred)
print("Accuracy score is: ",accuracy*100)
# Out:
# Accuracy score is:  71.31375221830714

# %% [markdown]
# > **2. Train and evaluate your model**

# %%
dataframe=pd.read_csv('modis_2018_Australia.csv')

y=dataframe.frp
x=dataframe.drop('frp',axis=1)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6)


model.fit(Xtrain, ytrain)                   
y_model = model.predict(Xtest)

# %% [markdown]
# > **3. How do you make sure not to overfit**
#
#
#
# > As mentioned in the previous question, to make sure the data is not overfit, we can use the hyperparameter tuning methods like cross validation, complexity check, random forest optimization traing the data from time to time in order to predict the data with more accuracy, etc. These techniques can help us in making sure that the data is not overfit and as a result we can expect great results.

# %% [markdown]
# > **4. Visualize the learning process and/or the knowledge acquired by your
# model. Explain why you think this is the right visualization.**
#
#
#
# >

# %%
plt.figure(figsize=(12, 6))

time = modis_2020['acq_time']
r_power = modis_2020['frp']
epochs = range(1,11)
plt.plot(time, r_power,label='Validation loss')
plt.title('Validation data')
plt.xlabel('complexity')
plt.ylabel('Score')
plt.legend()
plt.show()

# %% [markdown]
# > **5. Analyze the results**
#
#
#
# > Based on the data development and research analysis on this data learning assembling the data, traning the testing the models and making a progrssion classifier by more accurate through certain percent of estimators inside the project of train and test model with ramdom data selection and classification.

# %% [markdown]
# **7. Compare the two models with a statistical significance test. Use a box plot to
# visualize your comparison.**

# %% [markdown]
# Among the two models, grid-search algorithm is considered as the best algorithm to train, test and validate the model when compared with random forest detection algorithm. This is because, the grid-search algorithm pretty much covers all the combinational probabilities of the model with correct accuracy and relational estimators which results in high accuracy percentage of prediction model. Random forest hyper parameters deals with decision trees and random tree bagging selection.
